# %% [markdown]
# ### Notebook for viewing the replace and route outputs written to the data directory

# %%
import xarray as xr

# %%
ds = xr.open_dataset("../../../../data/output/PKTO1/troute_output_202505051800.nc", engine="netcdf4")
ds
# Out:
# <xarray.Dataset> Size: 16kB
# Dimensions:     (time: 96, feature_id: 10)
# Coordinates:
#   * time        (time) datetime64[ns] 768B 2025-05-05T19:00:00 ... 2025-05-09...
#   * feature_id  (feature_id) int64 80B 814942 814943 814944 ... 814950 814951
# Data variables:
#     type        (feature_id) <U2 80B ...
#     flow        (feature_id, time) float32 4kB ...
#     velocity    (feature_id, time) float32 4kB ...
#     depth       (feature_id, time) float32 4kB ...
#     nudge       (feature_id, time) float32 4kB ...
# Attributes:
#     TITLE:                OUTPUT FROM T-ROUTE
#     file_reference_time:  2025-05-05_18:00:00
#     code_version:

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 8))
ds.sel(feature_id=814942).flow.plot(ax=ax)
ds.sel(feature_id=814951).flow.plot(ax=ax)
