# %% [markdown]
# ### Notebook for viewing the replace and route outputs written to the data directory

# %%
import xarray as xr

# %%
ds = xr.open_dataset("troute_output_202505060600.nc", engine="netcdf4")
ds.feature_id
# Out:
# <xarray.DataArray 'feature_id' (feature_id: 22)> Size: 176B
# array([800137, 800138, 800139, 800140, 800141, 800142, 800143, 800144, 800145,
#        800146, 800147, 800148, 800149, 800150, 800151, 800152, 800153, 800154,
#        800155, 800156, 800157, 800158])
# Coordinates:
#   * feature_id  (feature_id) int64 176B 800137 800138 800139 ... 800157 800158
# Attributes:
#     long_name:  Segment ID

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 8))
ds.sel(feature_id=800137).flow.plot(ax=ax, label="Forecast point")
ds.sel(feature_id=800138).flow.plot(ax=ax, label="First downstream point")
ds.sel(feature_id=800139).flow.plot(ax=ax, label="Second downstream point")
ds.sel(feature_id=800140).flow.plot(ax=ax, label="Third downstream point")
plt.legend()
