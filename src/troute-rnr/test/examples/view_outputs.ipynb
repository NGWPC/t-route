# %% [markdown]
# ### Notebook for viewing the replace and route outputs written to the data directory

# %%
import xarray as xr

# %%
ds = xr.open_dataset("../../../../data/output/HPDT2/troute_output_202505060300.nc", engine="netcdf4")
ds.feature_id
# Out:
# <xarray.DataArray 'feature_id' (feature_id: 50)> Size: 400B
# array([2418120, 2418121, 2418122, 2418123, 2418124, 2418125, 2418126, 2418127,
#        2418128, 2418129, 2418130, 2418131, 2418132, 2418133, 2418134, 2418135,
#        2418136, 2418137, 2418138, 2418139, 2418140, 2418141, 2418142, 2418143,
#        2418144, 2418145, 2418146, 2418147, 2418148, 2418149, 2418150, 2418151,
#        2418152, 2418153, 2418154, 2418155, 2418156, 2418157, 2418158, 2418159,
#        2418160, 2418161, 2418162, 2418163, 2418164, 2418165, 2418166, 2418167,
#        2418168, 2418169])
# Coordinates:
#   * feature_id  (feature_id) int64 400B 2418120 2418121 ... 2418168 2418169
# Attributes:
#     long_name:  Segment ID

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 8))
ds.sel(feature_id=2418120).flow.plot(ax=ax, label="Forecast Point (reach_id: 2418120)")
ds.sel(feature_id=2418121).flow.plot(ax=ax, label="Downstream Point (reach_id: 2418121)")
ds.sel(feature_id=2418122).flow.plot(ax=ax, label="Downstream Point (reach_id: 2418122)")
ds.sel(feature_id=2418123).flow.plot(ax=ax, label="Downstream Point (reach_id: 2418123)")
plt.legend()
